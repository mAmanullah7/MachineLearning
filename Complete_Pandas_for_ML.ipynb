# %% [markdown]
# <a href="https://colab.research.google.com/github/mAmanullah7/MachineLearning/blob/main/Complete_Pandas_for_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Libaray;
# Useful for Data processing & Analysis
#
# Pandas Data Frame;
# Pandas Data frame is Two-Dimensional tabular data structure labled axes(rows and columns)

# %%
# importing the pandas library
import pandas as pd
import numpy as np

# %% [markdown]
# creating a pandas Datafame

# %%
# importing the boston house price data
from sklearn.datasets import load_boston

# %%
boston_dataset = load_boston()

# %%
type(boston_dataset)

# %%
print(boston_dataset)

# %%
# pandas dataframe
boston_df = pd.DataFrame(boston_dataset.data, columns = boston_dataset.feature_names )

# %%
boston_df.shape

# %% [markdown]
# importing the data from a csv file to a pandas DataFrame

# %%
# csb file to pandas df
diabetes_df = pd.read_csv('/diabetes.csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Loading the data from the excel file to Pandas file:
#
# pd.read_excel('file path')
#
#
# ---

# %% [markdown]
# Exporting a Pandas dataFrame to a CSV file;

# %%
boston_df.to_csv('boston.csv')
# we can export and download this file

# %% [markdown]
# Exporting a Pandas dataFrame to a Excel file;
#
# df.to_excel('filename')

# %%
# creating a dataframe with random values;
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.868615  0.090990  0.069216  0.373893  0.000481  0.406225  0.350173
# 1  0.726582  0.314769  0.343426  0.842319  0.456245  0.176001  0.847957
# 2  0.805930  0.860589  0.343380  0.317080  0.394516  0.252504  0.497985
# 3  0.303477  0.601707  0.322659  0.056971  0.213647  0.402612  0.259454
# 4  0.211324  0.410146  0.742337  0.546256  0.013193  0.104118  0.853485
#
#           7         8         9
# 0  0.899120  0.182948  0.141222
# 1  0.279762  0.747634  0.246719
# 2  0.973519  0.332303  0.911837
# 3  0.677595  0.084355  0.395154
# 4  0.985081  0.760508  0.320533

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# Inspecting a DataFrame

# %%
# Finding number rows and column
boston_df.shape

# %%
# first 5 rows in a Dataframe
boston_df.head()

# %%
# last five rows of thr dataFrame
boston_df.tail()

# %%
# Informations about the DataFrame
boston_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# finding the number missing values
boston_df.isnull().sum()
\
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# diabetes DataFrame
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# counting the vlaues based on labels
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
# Group the vaues  based on mean
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical Measures

# %%
# count or number of values
diabetes_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
# mean value - column wise
diabetes_df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
# Standard deviation - column wise
diabetes_df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
# minimum value
diabetes_df.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
# maximum value for each column
diabetes_df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
# all the statistical of the dataframe
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# Manipualting a DataFram

# %%
# Adding a column to DataFrame
boston_df['Price'] = boston_dataset.target

# %%
# removing a row
boston_df.drop(index = 0, axis = 0)

# %%
# drop a column
boston_df.drop(columns='ZN',axis = 1)

# %%
# loacating a - row using the index value
boston_df.iloc[2]

# %%
# loacating a - column
print(boston_df.iloc[:,0]) #first column
print(boston_df.iloc[:,1]) #second column
print(boston_df.iloc[:,2]) #third column
print(boston_df.iloc[:,1]) #all columns

# %% [markdown]
# Correletaion ;
# Positive Correletaion;
# Negative Correletaion;

# %%
boston_df.corr()
