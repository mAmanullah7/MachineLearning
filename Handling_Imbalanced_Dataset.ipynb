# %% [markdown]
# **Imbalanced Dataset:**
#
# A datset with an equal class distribution

# %%
# importing the dependecies
import numpy as np
import pandas as pd

# %%
# laoding the data set to pandas DataFrame
credit_card_data = pd.read_csv('/content/credit_data.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 3968  3617  1.134592  0.252051  0.488592  0.799826 -0.264819 -0.369918
# 3969  3621 -1.338671  1.080974  1.291196  0.719258  0.101320  0.053896
# 3970  3622 -0.339728 -2.417449  0.975517  2.537995 -1.720361  0.863005
# 3971  3623 -0.368639  0.947432  1.707755  0.932092  0.292956  0.189100
# 3972  3624 -0.663445  1.162921  1.508050  0.549405  0.231377 -0.106041
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 3968 -0.243365  0.049761  1.210818  ... -0.351115 -0.851463  0.186169
# 3969  0.001297 -0.917575  1.638510  ...  0.498030 -0.483932  0.037686
# 3970  0.032965  0.026764  2.487139  ...  0.391639  0.264432 -0.735031
# 3971  0.499330  0.132466  0.779412  ... -0.119045  0.056665 -0.172703
# 3972  0.817977 -0.387026  1.488054  ... -0.420337 -0.361357       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# ditribtion of the two classes
credit_card_data['Class'].value_counts()
# Out:
# 0.0    5970
# 1.0       3
# Name: Class, dtype: int64

# %% [markdown]
# This is a highly imbalanced Dataset
#
# 0 --> Legit Transaction
#
# 1 --> Fraudulent Transaction

# %%
# seperating the legit and fradulent transaction
legit = credit_card_data[credit_card_data.Class==0]
fraud = credit_card_data[credit_card_data.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (3970, 31)
# (2, 31)

# %% [markdown]
# Under-Sampling
#
# Build a simple dataset conataining similar distribution of Legit & Fradulent Transaction

# %%
legit_sample = legit.sample(n=3)

# %%
print(legit_sample.shape)
# Out:
# (2, 31)

# %% [markdown]
# Concatenate the two data frames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis = 0)    #axis = 0 means column wise addn

# %%
new_dataset.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1196   928  1.040172 -0.631707 -0.428630  0.050157  0.030965  0.443176
# 643    487  0.174857  2.035550 -1.866661  1.420853  0.829644 -1.683505
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1196 -0.054279  0.128924  0.485088  ... -0.233288 -1.001868 -0.280003
# 643   1.014476 -0.303887  0.196620  ... -0.233184 -0.111163  0.093547
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
#
#            V24       V25       V26       V27       V28  Amount  Class
# 1196 -1.386004  0.421703  0.523337 -0.087757  0.006541  158.00    0.0
# 643   0.159321 -0.414132 -0.443439  0.409371 -0.042075    8.99    0.0
# ...

# %%
new_dataset.tail()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1196   928  1.040172 -0.631707 -0.428630  0.050157  0.030965  0.443176
# 643    487  0.174857  2.035550 -1.866661  1.420853  0.829644 -1.683505
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1196 -0.054279  0.128924  0.485088  ... -0.233288 -1.001868 -0.280003
# 643   1.014476 -0.303887  0.196620  ... -0.233184 -0.111163  0.093547
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
#
#            V24       V25       V26       V27       V28  Amount  Class
# 1196 -1.386004  0.421703  0.523337 -0.087757  0.006541  158.00    0.0
# 643   0.159321 -0.414132 -0.443439  0.409371 -0.042075    8.99    0.0
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    2
# 1.0    2
# Name: Class, dtype: int64
